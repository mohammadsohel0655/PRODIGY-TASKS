# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file_path = '/mnt/data/world_population.csv'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96c863ba-65d8-4d8f-87aa-fc2198a11bc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96c863ba-65d8-4d8f-87aa-fc2198a11bc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/world_population.csv', skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)

# %%
chosen_country = 'Afghanistan'

country_data = df_final[df_final['Country Name'] == chosen_country]

year_columns = [col for col in country_data.columns if col.isdigit()]
years = list(map(int, year_columns))
population = country_data[year_columns].values.flatten()

plt.figure(figsize=(10, 5))
plt.bar(years, population, color='green')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {chosen_country} Over the Years')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(population, bins=20, color='green', edgecolor='white')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title(f'Histogram of Population Distribution for {chosen_country}')
plt.show()
